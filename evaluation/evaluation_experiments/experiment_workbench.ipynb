# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import sys
# Navigate up from 'dataset_filter' to 'evaluation', then 'information_retrieval', and up to the root
# Then access the 'rag_system' directory
sys.path.append("../../../rag_system/")
from RAG_evaluator import RAG_evaluator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 8
#       5 # Navigate up from 'dataset_filter' to 'evaluation', then 'information_retrieval', and up to the root
#       6 # Then access the 'rag_system' directory
#       7 sys.path.append("../../../rag_system/")
# ----> 8 from RAG_evaluator import RAG_evaluator
#
# ModuleNotFoundError: No module named 'RAG_evaluator'
